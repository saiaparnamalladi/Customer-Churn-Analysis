# %% [markdown]
# Clean and preprocess the raw customer churn dataset to make it fully suitable for machine learning models. This includes correcting data types, handling missing values, encoding categorical variables, and removing non-informative features. The output of this stage is a cleaned, fully numerical dataset saved for reuse in subsequent analysis and modeling stages.

# %%
df.to_csv("data/processed/cleaned_telco_churn.csv", index=False)
#saved the cleaned dataframe to a new CSV file

# %%
import os
os.getcwd()
# Get current working directory
os.chdir(r"C:\Users\MVS Sastri\Desktop\customer churn analytics")
# Change working directory to the project folder

# %%
bool_cols = df.select_dtypes(include="bool").columns
df[bool_cols] = df[bool_cols].astype(int)
df.info()  
#converted boolean columns to integer type

# %%
df = pd.get_dummies(df, drop_first=True)
#converted categorical columns to numerical using one-hot encoding
df.head()
df.info()

# %%
df["Churn"].unique()
#checking unique values in target variable 'Churn'

# %%
binary_cols = [
    "Partner",
    "Dependents",
    "PhoneService",
    "PaperlessBilling",
    "Churn"
]

for col in binary_cols:
    df[col] = df[col].map({"Yes": 1, "No": 0})

# %%
df.select_dtypes(include="object").columns
#checking remaining categorical columns

# %%
df["TotalCharges"].fillna(df["TotalCharges"].median(), inplace=True)
#filled missing values in 'TotalCharges' with median value

# %%
df.isnull().sum()
#checking for any remaining missing or null values

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
# converted 'TotalCharges' to numeric type

# %%
df.drop("customerID", axis=1, inplace=True)
#dropped 'customerID' column as it is not needed for analysis

# %%
df.info()
#used to check structure and data types of the dataframe after preprocessing

# %%
df.head()
#used to view the first few rows of the preprocessed dataframe

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\MVS Sastri\Desktop\customer churn analytics\data\raw\Telco-Customer-Churn.csv"
)
#loaded the dataset into a pandas DataFrame
