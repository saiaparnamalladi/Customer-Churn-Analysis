# %% [markdown]
# Objective: Load the raw customer churn dataset and perform an initial inspection to understand its structure, data types, and potential data quality issues. No modifications are performed in this stage.

# %%
df.info()
#final check of dataframe structure

# %%
df.head()
#preview the first few rows of the dataframe

# %%
import pandas as pd
df = pd.read_csv(
    r"C:\Users\MVS Sastri\Desktop\customer churn analytics\data\raw\Telco-Customer-Churn.csv"
)
#loaded the dataset into a pandas DataFrame
